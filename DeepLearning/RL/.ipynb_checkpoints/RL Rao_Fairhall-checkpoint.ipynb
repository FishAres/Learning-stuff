# %%
using Flux
using Distributions
using PyPlot
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\ares\.julia\compiled\v1.0\Flux\QdkVy.ji for Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1184
# WARNING: could not import NNlib.cudata into Tracker
# ┌ Info: Recompiling stale cache file C:\Users\ares\.julia\compiled\v1.0\Distributions\xILW0.ji for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1184

# %% [markdown]
# ![image.png](attachment:image.png)
